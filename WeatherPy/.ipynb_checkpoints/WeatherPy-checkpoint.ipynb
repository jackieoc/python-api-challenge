# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 578

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + f"&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atafu village
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | ola
# Processing Record 4 of Set 1 | temryuk
# Processing Record 5 of Set 1 | edinburgh of the seven seas
# Processing Record 6 of Set 1 | coahuayana de hidalgo
# Processing Record 7 of Set 1 | puerto natales
# Processing Record 8 of Set 1 | san antonio de pale
# Processing Record 9 of Set 1 | ouesso
# Processing Record 10 of Set 1 | nar'yan-mar
# Processing Record 11 of Set 1 | adamstown
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | carutapera
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | hadibu
# Processing Record 16 of Set 1 | iskateley
# Processing Record 17 of Set 1 | tamandare
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | dikhil
# Processing Record 20 of Set 1 | kobelyaky
# Processing Record 21 of Set 1 | egilsstadir
# Processing Record 22 of Set 1 | rongelap
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | kolonia
# Processing Record 26 of Set 1 | koneurgench
# City not found. Skipping...
# Processing Record 27 of Set 1 | waitangi
# Processing Record 28 of Set 1 | west island
# Processing Record 29 of Set 1 | kristinestad
# Processing Record 30 of Set 1 | afaahiti
# Processing Record 31 of Set 1 | klyuchi
# Processing Record 32 of Set 1 | cabo san lucas
# Processing Record 33 of Set 1 | francistown
# Processing Record 34 of Set 1 | whitehorse
# Processing Record 35 of Set 1 | nemuro
# Processing Record 36 of Set 1 | port douglas
# Processing Record 37 of Set 1 | grytviken
# Processing Record 38 of Set 1 | itoman
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | vila velha
# Processing Record 41 of Set 1 | aasiaat
# Processing Record 42 of Set 1 | belabo
# Processing Record 43 of Set 1 | lompoc
# Processing Record 44 of Set 1 | daru
# Processing Record 45 of Set 1 | laguna
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | uzhur
# Processing Record 48 of Set 1 | borogontsy
# Processing Record 49 of Set 1 | papatowai
# Processing Record 50 of Set 1 | mocorito
# Processing Record 0 of Set 2 | zyryanovsk
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | mount isa
# Processing Record 4 of Set 2 | manokwari
# Processing Record 5 of Set 2 | invercargill
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | long beach
# Processing Record 12 of Set 2 | port mathurin
# Processing Record 13 of Set 2 | nuuk
# Processing Record 14 of Set 2 | blackmans bay
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | nizhneangarsk
# Processing Record 17 of Set 2 | jan kempdorp
# Processing Record 18 of Set 2 | kharp
# Processing Record 19 of Set 2 | aginskoye
# Processing Record 20 of Set 2 | la passe
# Processing Record 21 of Set 2 | chishmy
# Processing Record 22 of Set 2 | laminusa
# Processing Record 23 of Set 2 | siverek
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | yaren
# Processing Record 26 of Set 2 | santiago del estero
# Processing Record 27 of Set 2 | talcahuano
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | troitsko-pechorsk
# Processing Record 30 of Set 2 | boulsa
# Processing Record 31 of Set 2 | queenstown
# Processing Record 32 of Set 2 | ust-nera
# Processing Record 33 of Set 2 | margaret river
# Processing Record 34 of Set 2 | constitucion
# Processing Record 35 of Set 2 | christchurch
# Processing Record 36 of Set 2 | toging am inn
# Processing Record 37 of Set 2 | bam
# Processing Record 38 of Set 2 | olyokminsk
# Processing Record 39 of Set 2 | berdigestyakh
# Processing Record 40 of Set 2 | velikiye luki
# Processing Record 41 of Set 2 | hawaiian paradise park
# Processing Record 42 of Set 2 | haverfordwest
# Processing Record 43 of Set 2 | fort bragg
# Processing Record 44 of Set 2 | palmer
# Processing Record 45 of Set 2 | lebu
# Processing Record 46 of Set 2 | kingston
# Processing Record 47 of Set 2 | altinekin
# Processing Record 48 of Set 2 | hamilton
# Processing Record 49 of Set 2 | taoudenni
# Processing Record 0 of Set 3 | zuunmod
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | olonkinbyen
# Processing Record 3 of Set 3 | tidjikja
# Processing Record 4 of Set 3 | mulanje
# Processing Record 5 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 6 of Set 3 | slave lake
# Processing Record 7 of Set 3 | suomussalmi
# Processing Record 8 of Set 3 | zakynthos
# Processing Record 9 of Set 3 | holualoa
# Processing Record 10 of Set 3 | bereznik
# Processing Record 11 of Set 3 | bilibino
# Processing Record 12 of Set 3 | vila franca do campo
# Processing Record 13 of Set 3 | constantia
# Processing Record 14 of Set 3 | yagry
# City not found. Skipping...
# Processing Record 15 of Set 3 | kone
# Processing Record 16 of Set 3 | vryburg
# Processing Record 17 of Set 3 | westport
# Processing Record 18 of Set 3 | sao joao da barra
# Processing Record 19 of Set 3 | zavetnoye
# Processing Record 20 of Set 3 | enewetak
# Processing Record 21 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 22 of Set 3 | ad dilam
# Processing Record 23 of Set 3 | casper
# Processing Record 24 of Set 3 | callao
# Processing Record 25 of Set 3 | pacocha
# Processing Record 26 of Set 3 | qaqortoq
# Processing Record 27 of Set 3 | hasaki
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | khandyga
# Processing Record 30 of Set 3 | wawa
# Processing Record 31 of Set 3 | la ronge
# Processing Record 32 of Set 3 | dalandzadgad
# Processing Record 33 of Set 3 | college
# Processing Record 34 of Set 3 | xunchang
# Processing Record 35 of Set 3 | la libertad
# Processing Record 36 of Set 3 | vadso
# Processing Record 37 of Set 3 | hollfeld
# Processing Record 38 of Set 3 | san felice circeo
# Processing Record 39 of Set 3 | chibougamau
# Processing Record 40 of Set 3 | buala
# Processing Record 41 of Set 3 | hotan
# Processing Record 42 of Set 3 | smirnovo
# Processing Record 43 of Set 3 | keflavik
# Processing Record 44 of Set 3 | oliver
# Processing Record 45 of Set 3 | badiyah
# Processing Record 46 of Set 3 | antonio enes
# Processing Record 47 of Set 3 | yerofey pavlovich
# Processing Record 48 of Set 3 | tambacounda
# Processing Record 49 of Set 3 | dunedin
# Processing Record 0 of Set 4 | jayapura
# Processing Record 1 of Set 4 | torremolinos
# Processing Record 2 of Set 4 | jatibonico
# Processing Record 3 of Set 4 | stanley
# Processing Record 4 of Set 4 | sudak
# Processing Record 5 of Set 4 | zhezqazghan
# Processing Record 6 of Set 4 | achinsk
# Processing Record 7 of Set 4 | alice springs
# Processing Record 8 of Set 4 | strenci
# Processing Record 9 of Set 4 | crane
# Processing Record 10 of Set 4 | priozersk
# Processing Record 11 of Set 4 | yuzhno-kurilsk
# Processing Record 12 of Set 4 | bikenibeu village
# Processing Record 13 of Set 4 | ribeira grande
# Processing Record 14 of Set 4 | weno
# Processing Record 15 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 16 of Set 4 | l'arbaa nait irathen
# Processing Record 17 of Set 4 | vernon
# Processing Record 18 of Set 4 | usinsk
# Processing Record 19 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 4 | sorong
# Processing Record 21 of Set 4 | mbandaka
# Processing Record 22 of Set 4 | wailua homesteads
# Processing Record 23 of Set 4 | amahai
# Processing Record 24 of Set 4 | isla del bosque
# Processing Record 25 of Set 4 | tamanrasset
# Processing Record 26 of Set 4 | bejaia
# Processing Record 27 of Set 4 | pitkyaranta
# Processing Record 28 of Set 4 | valparaiso
# Processing Record 29 of Set 4 | phan rang-thap cham
# Processing Record 30 of Set 4 | ketchikan
# Processing Record 31 of Set 4 | sitka
# Processing Record 32 of Set 4 | utrik
# Processing Record 33 of Set 4 | uzgen
# Processing Record 34 of Set 4 | osceola
# Processing Record 35 of Set 4 | papao
# Processing Record 36 of Set 4 | coquimbo
# Processing Record 37 of Set 4 | arkhangel'sk
# Processing Record 38 of Set 4 | antsiranana
# Processing Record 39 of Set 4 | altay
# Processing Record 40 of Set 4 | mulayjah
# Processing Record 41 of Set 4 | hermanus
# Processing Record 42 of Set 4 | saint-memmie
# Processing Record 43 of Set 4 | yuyao
# Processing Record 44 of Set 4 | aykhal
# Processing Record 45 of Set 4 | corralillo
# Processing Record 46 of Set 4 | haiku-pauwela
# Processing Record 47 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 48 of Set 4 | sinop
# Processing Record 49 of Set 4 | kamenka
# Processing Record 0 of Set 5 | margate
# Processing Record 1 of Set 5 | porto novo
# Processing Record 2 of Set 5 | manismata
# Processing Record 3 of Set 5 | dashitou
# Processing Record 4 of Set 5 | parauapebas
# Processing Record 5 of Set 5 | aars
# Processing Record 6 of Set 5 | maues
# Processing Record 7 of Set 5 | farsan
# Processing Record 8 of Set 5 | am timan
# Processing Record 9 of Set 5 | ilulissat
# Processing Record 10 of Set 5 | flying fish cove
# Processing Record 11 of Set 5 | colonia
# Processing Record 12 of Set 5 | broken hill
# Processing Record 13 of Set 5 | vorgashor
# Processing Record 14 of Set 5 | sandnessjoen
# Processing Record 15 of Set 5 | newman
# Processing Record 16 of Set 5 | naze
# Processing Record 17 of Set 5 | sambava
# Processing Record 18 of Set 5 | kas
# Processing Record 19 of Set 5 | novomykolayivka
# Processing Record 20 of Set 5 | airway heights
# Processing Record 21 of Set 5 | prien
# Processing Record 22 of Set 5 | touros
# Processing Record 23 of Set 5 | kanniyakumari
# Processing Record 24 of Set 5 | dolores
# Processing Record 25 of Set 5 | badger
# Processing Record 26 of Set 5 | igarka
# Processing Record 27 of Set 5 | at taraf
# Processing Record 28 of Set 5 | apac
# Processing Record 29 of Set 5 | shingu
# Processing Record 30 of Set 5 | starkville
# Processing Record 31 of Set 5 | labrador city
# Processing Record 32 of Set 5 | ushtobe
# Processing Record 33 of Set 5 | gisborne
# Processing Record 34 of Set 5 | pedernales
# Processing Record 35 of Set 5 | beira
# Processing Record 36 of Set 5 | rio bueno
# Processing Record 37 of Set 5 | hami
# Processing Record 38 of Set 5 | kem'
# Processing Record 39 of Set 5 | al-`ula
# City not found. Skipping...
# Processing Record 40 of Set 5 | okha
# Processing Record 41 of Set 5 | ebon
# Processing Record 42 of Set 5 | georgetown
# Processing Record 43 of Set 5 | san patricio
# Processing Record 44 of Set 5 | mariental
# Processing Record 45 of Set 5 | teluknaga
# Processing Record 46 of Set 5 | belel
# Processing Record 47 of Set 5 | chonchi
# Processing Record 48 of Set 5 | guiyang
# Processing Record 49 of Set 5 | sisimiut
# Processing Record 0 of Set 6 | tura
# Processing Record 1 of Set 6 | minas de marcona
# Processing Record 2 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 3 of Set 6 | undurkhaan
# Processing Record 4 of Set 6 | suzhou
# Processing Record 5 of Set 6 | selfoss
# Processing Record 6 of Set 6 | mejit
# Processing Record 7 of Set 6 | igrim
# Processing Record 8 of Set 6 | basco
# Processing Record 9 of Set 6 | gandorhun
# Processing Record 10 of Set 6 | robertsport
# Processing Record 11 of Set 6 | masaurhi buzurg
# Processing Record 12 of Set 6 | punta arenas
# Processing Record 13 of Set 6 | luderitz
# Processing Record 14 of Set 6 | portales
# Processing Record 15 of Set 6 | port elizabeth
# Processing Record 16 of Set 6 | cam ranh
# Processing Record 17 of Set 6 | ardabil
# Processing Record 18 of Set 6 | xinxiang
# Processing Record 19 of Set 6 | green river
# Processing Record 20 of Set 6 | quellon
# Processing Record 21 of Set 6 | acapulco de juarez
# Processing Record 22 of Set 6 | riosucio
# Processing Record 23 of Set 6 | bodaybo
# Processing Record 24 of Set 6 | peace river
# Processing Record 25 of Set 6 | barclayville
# Processing Record 26 of Set 6 | auki
# Processing Record 27 of Set 6 | zabol
# Processing Record 28 of Set 6 | dudinka
# Processing Record 29 of Set 6 | kerikeri
# Processing Record 30 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 31 of Set 6 | novofedorivka
# Processing Record 32 of Set 6 | meadow lake
# Processing Record 33 of Set 6 | northam
# Processing Record 34 of Set 6 | anadyr
# Processing Record 35 of Set 6 | rosarito
# Processing Record 36 of Set 6 | pagar alam
# Processing Record 37 of Set 6 | dragor
# Processing Record 38 of Set 6 | shenjiamen
# Processing Record 39 of Set 6 | lerwick
# Processing Record 40 of Set 6 | nema
# Processing Record 41 of Set 6 | kalmunai
# Processing Record 42 of Set 6 | pizarro
# Processing Record 43 of Set 6 | marsaskala
# City not found. Skipping...
# Processing Record 44 of Set 6 | la leonesa
# Processing Record 45 of Set 6 | qamdo
# Processing Record 46 of Set 6 | kavaratti
# Processing Record 47 of Set 6 | tevriz
# Processing Record 48 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 0 of Set 7 | udachny
# Processing Record 1 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 2 of Set 7 | fale old settlement
# Processing Record 3 of Set 7 | richfield
# Processing Record 4 of Set 7 | gueltat zemmour
# City not found. Skipping...
# Processing Record 5 of Set 7 | smithers
# Processing Record 6 of Set 7 | pandan
# Processing Record 7 of Set 7 | isangel
# Processing Record 8 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 9 of Set 7 | katabu
# Processing Record 10 of Set 7 | grants
# Processing Record 11 of Set 7 | kill devil hills
# Processing Record 12 of Set 7 | piti village
# Processing Record 13 of Set 7 | ust'-ilimsk
# Processing Record 14 of Set 7 | fortuna
# Processing Record 15 of Set 7 | villa gesell
# Processing Record 16 of Set 7 | mermoz boabab
# Processing Record 17 of Set 7 | kudahuvadhoo
# Processing Record 18 of Set 7 | benguela
# Processing Record 19 of Set 7 | sao lourenco do sul
# Processing Record 20 of Set 7 | nagqu
# Processing Record 21 of Set 7 | quzhou
# Processing Record 22 of Set 7 | san agustin de valle fertil
# Processing Record 23 of Set 7 | saipan
# Processing Record 24 of Set 7 | demidov
# Processing Record 25 of Set 7 | ancud
# Processing Record 26 of Set 7 | port glaud
# City not found. Skipping...
# Processing Record 27 of Set 7 | puerto baquerizo moreno
# Processing Record 28 of Set 7 | san andros
# City not found. Skipping...
# Processing Record 29 of Set 7 | turi
# Processing Record 30 of Set 7 | aljezur
# Processing Record 31 of Set 7 | bereket
# Processing Record 32 of Set 7 | barra de santo antonio
# Processing Record 33 of Set 7 | opuwo
# Processing Record 34 of Set 7 | bowen
# Processing Record 35 of Set 7 | polyarnyy
# Processing Record 36 of Set 7 | tsagan aman
# Processing Record 37 of Set 7 | lihue
# Processing Record 38 of Set 7 | sishilichengzi
# City not found. Skipping...
# Processing Record 39 of Set 7 | eenhana
# Processing Record 40 of Set 7 | trenton
# Processing Record 41 of Set 7 | nouadhibou
# Processing Record 42 of Set 7 | corinto
# Processing Record 43 of Set 7 | isafjordur
# Processing Record 44 of Set 7 | magadan
# Processing Record 45 of Set 7 | suva
# Processing Record 46 of Set 7 | lethem
# Processing Record 47 of Set 7 | carolina
# Processing Record 48 of Set 7 | brookings
# Processing Record 49 of Set 7 | tazovsky
# Processing Record 0 of Set 8 | pisco
# Processing Record 1 of Set 8 | susuman
# Processing Record 2 of Set 8 | cururupu
# Processing Record 3 of Set 8 | remire-montjoly
# Processing Record 4 of Set 8 | uturoa
# Processing Record 5 of Set 8 | kasama
# Processing Record 6 of Set 8 | gorontalo
# Processing Record 7 of Set 8 | qorveh
# Processing Record 8 of Set 8 | bamboo flat
# Processing Record 9 of Set 8 | saudarkrokur
# Processing Record 10 of Set 8 | ar ruways
# Processing Record 11 of Set 8 | at tall al kabir
# Processing Record 12 of Set 8 | greymouth
# Processing Record 13 of Set 8 | vanimo
# Processing Record 14 of Set 8 | shache
# Processing Record 15 of Set 8 | juneau
# Processing Record 16 of Set 8 | kavieng
# Processing Record 17 of Set 8 | howard springs
# Processing Record 18 of Set 8 | rio gallegos
# Processing Record 19 of Set 8 | trasacco
# Processing Record 20 of Set 8 | lazaro cardenas
# Processing Record 21 of Set 8 | labytnangi
# Processing Record 22 of Set 8 | we
# City not found. Skipping...
# Processing Record 23 of Set 8 | maceio
# Processing Record 24 of Set 8 | gwalior
# Processing Record 25 of Set 8 | puerto armuelles
# Processing Record 26 of Set 8 | siocon
# Processing Record 27 of Set 8 | south portland
# Processing Record 28 of Set 8 | cloquet
# Processing Record 29 of Set 8 | betio village
# Processing Record 30 of Set 8 | kuanda
# Processing Record 31 of Set 8 | burang
# Processing Record 32 of Set 8 | turinsk
# Processing Record 33 of Set 8 | watsa
# Processing Record 34 of Set 8 | nuku'alofa
# Processing Record 35 of Set 8 | brisas de zicatela
# Processing Record 36 of Set 8 | floro
# Processing Record 37 of Set 8 | pacasmayo
# Processing Record 38 of Set 8 | ciudad lazaro cardenas
# Processing Record 39 of Set 8 | yibin
# Processing Record 40 of Set 8 | yangshuo
# Processing Record 41 of Set 8 | richmond
# Processing Record 42 of Set 8 | castanos
# Processing Record 43 of Set 8 | baruun-urt
# Processing Record 44 of Set 8 | ponta pora
# Processing Record 45 of Set 8 | codrington
# Processing Record 46 of Set 8 | portland
# Processing Record 47 of Set 8 | conceicao da barra
# Processing Record 48 of Set 8 | nova sintra
# Processing Record 49 of Set 8 | popondetta
# Processing Record 0 of Set 9 | arvayheer
# Processing Record 1 of Set 9 | bonito
# Processing Record 2 of Set 9 | regina
# Processing Record 3 of Set 9 | capinzal
# Processing Record 4 of Set 9 | grand-lahou
# Processing Record 5 of Set 9 | st. john's
# Processing Record 6 of Set 9 | villa mercedes
# Processing Record 7 of Set 9 | karratha
# Processing Record 8 of Set 9 | khuzdar
# Processing Record 9 of Set 9 | broome
# Processing Record 10 of Set 9 | santa ines
# Processing Record 11 of Set 9 | georgiyevka
# Processing Record 12 of Set 9 | kaa-khem
# Processing Record 13 of Set 9 | yauya
# Processing Record 14 of Set 9 | alaghsas
# Processing Record 15 of Set 9 | meiktila
# Processing Record 16 of Set 9 | tofol
# Processing Record 17 of Set 9 | nyurba
# Processing Record 18 of Set 9 | east london
# Processing Record 19 of Set 9 | embi
# Processing Record 20 of Set 9 | tan-tan
# Processing Record 21 of Set 9 | talnakh
# Processing Record 22 of Set 9 | akureyri
# Processing Record 23 of Set 9 | mumford
# Processing Record 24 of Set 9 | nelson
# Processing Record 25 of Set 9 | sao felix do xingu
# Processing Record 26 of Set 9 | damara
# Processing Record 27 of Set 9 | la foa
# Processing Record 28 of Set 9 | bafoulabe
# Processing Record 29 of Set 9 | kidal
# Processing Record 30 of Set 9 | great bend
# Processing Record 31 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 32 of Set 9 | mukalla
# Processing Record 33 of Set 9 | puerto carreno
# Processing Record 34 of Set 9 | vikhorevka
# Processing Record 35 of Set 9 | galle
# Processing Record 36 of Set 9 | skikda
# Processing Record 37 of Set 9 | worland
# Processing Record 38 of Set 9 | hacienda huancane
# Processing Record 39 of Set 9 | humen
# Processing Record 40 of Set 9 | atamyrat
# Processing Record 41 of Set 9 | carnarvon
# Processing Record 42 of Set 9 | fougamou
# Processing Record 43 of Set 9 | vilyuchinsk
# Processing Record 44 of Set 9 | kulia village
# City not found. Skipping...
# Processing Record 45 of Set 9 | khandallah
# Processing Record 46 of Set 9 | lamu
# Processing Record 47 of Set 9 | at taj
# Processing Record 48 of Set 9 | sonoita
# Processing Record 49 of Set 9 | aur
# Processing Record 0 of Set 10 | winnemucca
# Processing Record 1 of Set 10 | villa la angostura
# Processing Record 2 of Set 10 | shakiso
# Processing Record 3 of Set 10 | arteche
# Processing Record 4 of Set 10 | tazacorte
# Processing Record 5 of Set 10 | vondrozo
# Processing Record 6 of Set 10 | manta
# Processing Record 7 of Set 10 | rawai
# Processing Record 8 of Set 10 | charters towers
# Processing Record 9 of Set 10 | itaituba
# Processing Record 10 of Set 10 | bargaal
# Processing Record 11 of Set 10 | praia da vitoria
# Processing Record 12 of Set 10 | makoua
# Processing Record 13 of Set 10 | puerto santa
# Processing Record 14 of Set 10 | tommot
# Processing Record 15 of Set 10 | kangaba
# Processing Record 16 of Set 10 | tlahualilo de zaragoza
# Processing Record 17 of Set 10 | formosa do rio preto
# Processing Record 18 of Set 10 | castillos
# Processing Record 19 of Set 10 | usogorsk
# Processing Record 20 of Set 10 | upper sandusky
# Processing Record 21 of Set 10 | wenchang
# Processing Record 22 of Set 10 | pauini
# Processing Record 23 of Set 10 | thousand palms
# Processing Record 24 of Set 10 | taltal
# Processing Record 25 of Set 10 | griffith
# Processing Record 26 of Set 10 | goure
# Processing Record 27 of Set 10 | morteau
# Processing Record 28 of Set 10 | tyuratam
# Processing Record 29 of Set 10 | richards bay
# Processing Record 30 of Set 10 | darab
# Processing Record 31 of Set 10 | odry
# Processing Record 32 of Set 10 | emirdag
# Processing Record 33 of Set 10 | siwa oasis
# Processing Record 34 of Set 10 | khilok
# Processing Record 35 of Set 10 | dedovichi
# Processing Record 36 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 37 of Set 10 | fedorovskiy
# Processing Record 38 of Set 10 | gillette
# Processing Record 39 of Set 10 | baharly
# Processing Record 40 of Set 10 | atkarsk
# Processing Record 41 of Set 10 | las vegas
# Processing Record 42 of Set 10 | barmer
# Processing Record 43 of Set 10 | pionerskiy
# Processing Record 44 of Set 10 | kalibo (poblacion)
# Processing Record 45 of Set 10 | el calafate
# Processing Record 46 of Set 10 | fort mcmurray
# Processing Record 47 of Set 10 | prince rupert
# Processing Record 48 of Set 10 | bardai
# Processing Record 49 of Set 10 | morozovsk
# Processing Record 0 of Set 11 | el porvenir
# Processing Record 1 of Set 11 | nanao
# Processing Record 2 of Set 11 | borkum
# Processing Record 3 of Set 11 | labuan
# Processing Record 4 of Set 11 | cabedelo
# Processing Record 5 of Set 11 | governador dix sept rosado
# Processing Record 6 of Set 11 | anamosa
# Processing Record 7 of Set 11 | kudat
# Processing Record 8 of Set 11 | namie
# Processing Record 9 of Set 11 | happy valley-goose bay
# Processing Record 10 of Set 11 | djibo
# Processing Record 11 of Set 11 | al jawf
# Processing Record 12 of Set 11 | sharypovo
# Processing Record 13 of Set 11 | berezovyy
# Processing Record 14 of Set 11 | urangan
# Processing Record 15 of Set 11 | tbeng meanchey
# Processing Record 16 of Set 11 | deyang
# Processing Record 17 of Set 11 | shumikha
# Processing Record 18 of Set 11 | princeville
# Processing Record 19 of Set 11 | andkhoy
# Processing Record 20 of Set 11 | safotu
# Processing Record 21 of Set 11 | hilo
# Processing Record 22 of Set 11 | la sarre
# Processing Record 23 of Set 11 | nicoya
# Processing Record 24 of Set 11 | zeya
# Processing Record 25 of Set 11 | laayoune
# Processing Record 26 of Set 11 | fisterra
# Processing Record 27 of Set 11 | korla
# Processing Record 28 of Set 11 | lagodekhi
# Processing Record 29 of Set 11 | kapuskasing
# Processing Record 30 of Set 11 | linares
# Processing Record 31 of Set 11 | kruisfontein
# Processing Record 32 of Set 11 | mandal
# Processing Record 33 of Set 11 | neryungri
# Processing Record 34 of Set 11 | ginir
# Processing Record 35 of Set 11 | shanghai
# Processing Record 36 of Set 11 | namibe
# Processing Record 37 of Set 11 | xining
# Processing Record 38 of Set 11 | ayame
# Processing Record 39 of Set 11 | balasore
# Processing Record 40 of Set 11 | illizi
# Processing Record 41 of Set 11 | slany
# Processing Record 42 of Set 11 | fyodorovka
# Processing Record 43 of Set 11 | koson
# Processing Record 44 of Set 11 | al 'alamayn
# City not found. Skipping...
# Processing Record 45 of Set 11 | laojunmiao
# Processing Record 46 of Set 11 | medina
# Processing Record 47 of Set 11 | soio
# Processing Record 48 of Set 11 | gadzhiyevo
# Processing Record 49 of Set 11 | altai
# Processing Record 0 of Set 12 | marco island
# Processing Record 1 of Set 12 | verkhovyna
# Processing Record 2 of Set 12 | obo
# Processing Record 3 of Set 12 | plombieres
# Processing Record 4 of Set 12 | tolanaro
# Processing Record 5 of Set 12 | mount gambier
# Processing Record 6 of Set 12 | strathmore
# Processing Record 7 of Set 12 | kingscliff
# Processing Record 8 of Set 12 | borgo val di taro
# Processing Record 9 of Set 12 | belmonte
# Processing Record 10 of Set 12 | pitimbu
# Processing Record 11 of Set 12 | misratah
# Processing Record 12 of Set 12 | acarau
# Processing Record 13 of Set 12 | barreirinha
# Processing Record 14 of Set 12 | benjamin constant
# Processing Record 15 of Set 12 | holma
# Processing Record 16 of Set 12 | le port
# Processing Record 17 of Set 12 | tarfaya
# Processing Record 18 of Set 12 | nukunonu
# City not found. Skipping...
# Processing Record 19 of Set 12 | lymanka
# City not found. Skipping...
# Processing Record 20 of Set 12 | wickenburg
# Processing Record 21 of Set 12 | poronaysk
# Processing Record 22 of Set 12 | liuli
# Processing Record 23 of Set 12 | dampit
# Processing Record 24 of Set 12 | nova vicosa
# Processing Record 25 of Set 12 | lautoka
# Processing Record 26 of Set 12 | buka
# Processing Record 27 of Set 12 | lorengau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          554
# Lat           554
# Lng           554
# Max Temp      554
# Humidity      554
# Cloudiness    554
# Wind Speed    554
# Country       554
# Date          554
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                atafu village  -8.5421 -172.5159     27.73        79
# 1                 puerto ayora  -0.7393  -90.3518     28.98        90
# 2                          ola  59.5833  151.2833     11.35        66
# 3                      temryuk  45.2722   37.3811     29.12        30
# 4  edinburgh of the seven seas -37.0676  -12.3116     13.33        78
#
#    Cloudiness  Wind Speed Country        Date
# 0          51        4.96      TK  1691255806
# 1          42        4.02      EC  1691255806
# 2          99        2.86      RU  1691255806
# 3           0        6.81      RU  1691255703
# 4          10       15.31      SH  1691255807

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      atafu village  -8.5421 -172.5159     27.73        79
# 1                       puerto ayora  -0.7393  -90.3518     28.98        90
# 2                                ola  59.5833  151.2833     11.35        66
# 3                            temryuk  45.2722   37.3811     29.12        30
# 4        edinburgh of the seven seas -37.0676  -12.3116     13.33        78
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                51        4.96      TK  1691255806
# 1                42        4.02      EC  1691255806
# 2                99        2.86      RU  1691255806
# 3                 0        6.81      RU  1691255703
# 4                10       15.31      SH  1691255807

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values= city_data_df["Lat"]
y_values = city_data_df["Max Temp"]
plt.scatter(x_values, y_values)


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values= city_data_df["Lat"]
y_values = city_data_df["Humidity"]
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values= city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
 

# Display sample data
northern_hemi_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                          ola  59.5833  151.2833     11.35        66
# 3                      temryuk  45.2722   37.3811     29.12        30
# 5        coahuayana de hidalgo  18.7000 -103.6583     32.36        50
# 8                       ouesso   1.6136   16.0517     25.97        71
# 9                  nar'yan-mar  67.6713   53.0870     21.91        72
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                99        2.86      RU  1691255806
# 3                 0        6.81      RU  1691255703
# 5               100        1.09      MX  1691255807
# 8                96        0.93      CG  1691255807
# 9                89        3.60      RU  1691255807

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <= 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      atafu village  -8.5421 -172.5159     27.73        79
# 1                       puerto ayora  -0.7393  -90.3518     28.98        90
# 4        edinburgh of the seven seas -37.0676  -12.3116     13.33        78
# 6                     puerto natales -51.7236  -72.4875      5.84        83
# 7                san antonio de pale  -1.4014    5.6325     22.85        79
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                51        4.96      TK  1691255806
# 1                42        4.02      EC  1691255806
# 4                10       15.31      SH  1691255807
# 6                96        8.64      CL  1691255807
# 7                97        5.32      GQ  1691255807

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
print(f"R squared: {rvalue**2}")
# Out:
# R squared: 0.3857650849181958

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
print(f"R squared: {rvalue**2}")
# Out:
# R squared: 0.6820550748090056

# %% [markdown]
# **Discussion about the linear relationship:** It seems that there is a weak correlation(0.38) between Latitude and Temperature in the Northern Hemisphere and a moderate correlation (0.68) in the Southern Hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
print(f"R squared: {rvalue**2}")
# Out:
# R squared: 0.0010584781481197938

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
print(f"R squared: {rvalue**2}")
# Out:
# R squared: 0.0061899481315910495

# %% [markdown]
# **Discussion about the linear relationship: There is no correlation between Latitude and humidity in either Hemisphere (NH: 0.001 and SH: 0.006).

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
print(f"R squared: {rvalue**2}")
# Out:
# R squared: 0.00032947598808579463

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
print(f"R squared: {rvalue**2}")
# Out:
# R squared: 0.009788296024277662

# %% [markdown]
# **Discussion about the linear relationship:**There is no correlation between latitude and cloudiness in either Hemisphere (NH: 0.003, SH: 0.009)

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
print(f"R squared: {rvalue**2}")
# Out:
# R squared: 0.00857328489871942

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
print(f"R squared: {rvalue**2}")
# Out:
# R squared: 0.010216476222474596

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation between latitude and wind speed in either Hemisphere (NH: 0.008, SH: 0.01)
